# %% [markdown]
# # OptiGuide Example

# %% [markdown]
# Here we give a simple example, as designed and illustrated in the [OptiGuide paper](https://arxiv.org/abs/2307.03875).
# While the original paper is designed specifically for supply chain optimization, the general framework can be easily adapted to other applications with coding capacity.

# %% [markdown]
# ## OptiGuide for Supply Chain Optimization: System Design Overview
#
# The original system design for OptiGuide, tailored for supply chain optimization, is presented below.
#
# The collaboration among three agents -- Coder, Safeguard, and Interpreter -- lies at the core of this system. They leverage a set of external tools and a large language model (LLM) to address users' questions related to supply chain applications. For a comprehensive understanding of the design and data flow, detailed information can be found in the original [paper](https://arxiv.org/abs/2307.03875).
#
#
# ![optiguide system](https://www.beibinli.com/docs/optiguide/optiguide_system.png)

# %% [markdown]
# ## New Implementation
#
#
#
# ![](new_design.png)
#
# Advantages of this multi-agent design with autogen:
# - Collaborative Problem Solving: The collaboration among the user proxy agent and the assistant agents fosters a cooperative problem-solving environment. The agents can share information and knowledge, allowing them to complement each other's abilities and collectively arrive at better solutions. On the other hand, the Safeguard acts as a virtual adversarial checker, which can perform another safety check pass on the generated code.
#
# - Modularity: The division of tasks into separate agents promotes modularity in the system. Each agent can be developed, tested, and maintained independently, simplifying the overall development process and facilitating code management.
#
# - Memory Management: The OptiGuide agent's role in maintaining memory related to user interactions is crucial. The memory retention allows the agents to have context about a user's prior questions, making the decision-making process more informed and context-aware.

# %%
# Install Required Packages
# %pip install optiguide
# Out:
# Requirement already satisfied: optiguide in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (0.0.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: openai in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from optiguide) (0.28.1)
# Requirement already satisfied: diskcache in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from optiguide) (5.6.3)
# Requirement already satisfied: termcolor in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from optiguide) (2.3.0)
# Requirement already satisfied: flaml in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from optiguide) (2.1.1)
# Requirement already satisfied: autogen in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from optiguide) (1.0.16)
# Requirement already satisfied: eventlet in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from optiguide) (0.33.3)
# Requirement already satisfied: gurobipy in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from optiguide) (10.0.3)
# Requirement already satisfied: PyYAML in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from autogen->optiguide) (6.0.1)
# Requirement already satisfied: autopep8 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from autogen->optiguide) (2.0.4)
# Requirement already satisfied: docopt in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from autogen->optiguide) (0.6.2)
# Requirement already satisfied: setuptools in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from autogen->optiguide) (65.5.0)
# Requirement already satisfied: twine in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from autogen->optiguide) (4.0.2)
# Requirement already satisfied: dnspython>=1.15.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from eventlet->optiguide) (2.4.2)
# Requirement already satisfied: greenlet>=0.3 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from eventlet->optiguide) (3.0.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from eventlet->optiguide) (1.16.0)
# Requirement already satisfied: NumPy>=1.17.0rc1 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from flaml->optiguide) (1.26.1)
# Requirement already satisfied: requests>=2.20 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from openai->optiguide) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from openai->optiguide) (4.66.1)
# Requirement already satisfied: aiohttp in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from openai->optiguide) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from requests>=2.20->openai->optiguide) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from requests>=2.20->openai->optiguide) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from requests>=2.20->openai->optiguide) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from requests>=2.20->openai->optiguide) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from aiohttp->openai->optiguide) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from aiohttp->openai->optiguide) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from aiohttp->openai->optiguide) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from aiohttp->openai->optiguide) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from aiohttp->openai->optiguide) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from aiohttp->openai->optiguide) (1.3.1)
# Requirement already satisfied: pycodestyle>=2.10.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from autopep8->autogen->optiguide) (2.11.1)
# Requirement already satisfied: colorama in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from tqdm->openai->optiguide) (0.4.6)
# Requirement already satisfied: pkginfo>=1.8.1 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from twine->autogen->optiguide) (1.9.6)
# Requirement already satisfied: readme-renderer>=35.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from twine->autogen->optiguide) (42.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from twine->autogen->optiguide) (1.0.0)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from twine->autogen->optiguide) (6.8.0)
# Requirement already satisfied: keyring>=15.1 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from twine->autogen->optiguide) (24.2.0)
# Requirement already satisfied: rfc3986>=1.4.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from twine->autogen->optiguide) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from twine->autogen->optiguide) (13.6.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from importlib-metadata>=3.6->twine->autogen->optiguide) (3.17.0)
# Requirement already satisfied: jaraco.classes in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from keyring>=15.1->twine->autogen->optiguide) (3.3.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from keyring>=15.1->twine->autogen->optiguide) (0.2.2)
# Requirement already satisfied: nh3>=0.2.14 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from readme-renderer>=35.0->twine->autogen->optiguide) (0.2.14)
# Requirement already satisfied: docutils>=0.13.1 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from readme-renderer>=35.0->twine->autogen->optiguide) (0.20.1)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from readme-renderer>=35.0->twine->autogen->optiguide) (2.16.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from rich>=12.0.0->twine->autogen->optiguide) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->autogen->optiguide) (0.1.2)
# Requirement already satisfied: more-itertools in c:\users\linda\desktop\capstone\capstonevenv\lib\site-packages (from jaraco.classes->keyring>=15.1->twine->autogen->optiguide) (10.1.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# test Gurobi installation
import gurobipy as gp
from gurobipy import GRB
from eventlet.timeout import Timeout

# import auxillary packages
import re
import requests  # for loading the example source code
import openai
import os

# import flaml and autogen
from flaml import autogen
from flaml.autogen.agentchat import Agent, UserProxyAgent
from optiguide.optiguide import OptiGuideAgent

# %%
openai.api_key_path = "OAI_CONFIG_LIST.txt"

# %%
autogen.oai.ChatCompletion.start_logging()

config_list = autogen.config_list_from_json(
    "OAI_CONFIG_LIST",
    filter_dict={
        "model": {
            "gpt-4",
            "gpt4",
            "gpt-4-32k",
            "gpt-4-32k-0314",
            "gpt-3.5-turbo",
            "gpt-3.5-turbo-16k",
            "gpt-3.5-turbo-0301",
            "chatgpt-35-turbo-0301",
            "gpt-35-turbo-v0301",
        }
    }
)

# %% [markdown]
# Now, let's import the source code (loading from URL) and also some training examples (defined as string blow).

# %%
# Get the source code of our coffee example
code_url = "https://raw.githubusercontent.com/microsoft/OptiGuide/main/benchmark/application/coffee.py"
response  = requests.get(code_url)
# Check if the request was successful
if response.status_code == 200:
    # Get the text content from the response
    code = response.text
else:
    raise RuntimeError("Failed to retrieve the file.")
# code = open(code_url, "r").read() # for local files


# show the first head and tail of the source code
print("\n".join(code.split("\n")[:10]))
print(".\n" * 3)
print("\n".join(code.split("\n")[-10:]))
# Out:
# import time
# from gurobipy import GRB, Model
#
# # Example data
#
# capacity_in_supplier = {'supplier1': 150, 'supplier2': 50, 'supplier3': 100}
#
# shipping_cost_from_supplier_to_roastery = {
#     ('supplier1', 'roastery1'): 5,
#     ('supplier1', 'roastery2'): 4,
# .
# .
# .
#
# # Solve
# m.update()
# model.optimize()
#
# print(time.ctime())
# if m.status == GRB.OPTIMAL:
#     print(f'Optimal cost: {m.objVal}')
# else:
#     print("Not solved to optimality. Optimization status:", m.status)

# %%
# In-context learning examples.
example_qa = """
----------
Question: Why is it not recommended to rely on just one seed supplier for Farm 2?
Answer Code:
```python
z = model.addVars(suppliers, vtype=GRB.BINARY, name="z")
model.addConstr(sum(z[s] for s in suppliers) <= 1, "one_supplier_constraint")
for s in suppliers:
    model.addConstr(x[s, 'farm2'] <= seed_supply_capacity[s] * z[s], "capacity_constraint_farm2")
```

----------
Question: How can we adjust the model if we want to explore a scenario where the planting cost at Farm 1 increases by 10%?
Answer Code:
```python
planting_cost['farm1'] = planting_cost['farm1'] * 1.10
# Update the Objective Function to Reflect New Costs
model.setObjective(
    sum(x[i] * transport_cost_supplier_to_farm[i] for i in transport_cost_supplier_to_farm.keys()) +
    sum(y[j] * transport_cost_farm_to_market[j] for j in transport_cost_farm_to_market.keys()) +
    sum(planting_cost[f] * sum(y[f, m] for m in markets) for f in farms) +
    sum(storage_preservation_cost[m] * market_demand[m] for m in markets),
    GRB.MINIMIZE)

```


"""

# %% [markdown]
# Now, let's create an OptiGuide agent and also a user.
#
# For the OptiGuide agent, we only allow "debug_times" to be 1, which means it can debug its answer once if it encountered errors.

# %%
# %%capture
agent = OptiGuideAgent(name="OptiGuide Coffee Example",
                  source_code=code,
                   debug_times=1,
                  example_qa="",
                llm_config={
        "request_timeout": 600,
        "seed": 42,
        "config_list": config_list,
    })

user = UserProxyAgent("user", max_consecutive_auto_reply=0,
                         human_input_mode="NEVER", code_execution_config=False)

# %% [markdown]
# Now, let's create a user's question.

# %%
user.initiate_chat(agent, message="What if we prohibit shipping from supplier 1 to roastery 2?")
# Out:
# user (to OptiGuide Coffee Example):
#
# What if we prohibit shipping from supplier 1 to roastery 2?
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Coffee Example):
#
# ```python
# # Prohibit shipping from supplier 1 to roastery 2 by setting the variable to 0
# model.addConstr(x['supplier1', 'roastery2'] == 0)
# ```
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to safeguard):
#
#
# --- Code ---
# # Prohibit shipping from supplier 1 to roastery 2 by setting the variable to 0
# model.addConstr(x['supplier1', 'roastery2'] == 0)
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# safeguard (to OptiGuide Coffee Example):
#
# SAFE
#
# --------------------------------------------------------------------------------
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 11 rows, 18 columns and 36 nonzeros
# Model fingerprint: 0x2d91b9ad
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 2e+02]
# Found heuristic solution: objective 3280.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 18 columns, 36 nonzeros
# Variable types: 0 continuous, 18 integer (0 binary)
# Found heuristic solution: objective 3276.0000000
#
# Root relaxation: objective 2.470000e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2470.0000000 2470.00000  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 2470 3276 3280
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.470000000000e+03, best bound 2.470000000000e+03, gap 0.0000%
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12 rows, 18 columns and 37 nonzeros
# Model fingerprint: 0xdb69a16b
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 2e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R11 by 80.000000000
#
# Found heuristic solution: objective 3280.0000000
# Presolve removed 2 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 17 columns, 33 nonzeros
# Variable types: 0 continuous, 17 integer (0 binary)
# Found heuristic solution: objective 3275.0000000
#
# Root relaxation: objective 2.760000e+03, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2760.0000000 2760.00000  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 2760 3275 3280
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.760000000000e+03, best bound 2.760000000000e+03, gap 0.0000%
# Sun Nov  5 20:09:35 2023
# Optimal cost: 2760.0
# Optimization problem solved. The objective value is: 2760.0
# OptiGuide Coffee Example (to writer):
#
# Here are the execution results: Optimization problem solved. The objective value is: 2760.0
#
# Can you organize these information to a human readable answer?
# Remember to compare the new results to the original results you obtained in the
# beginning.
#
# --- HUMAN READABLE ANSWER ---
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Coffee Example):
#
# By prohibiting the shipment from supplier 1 to roastery 2, the optimal cost of the supply chain increased from 2470.0 to 2760.0. This means the restriction made the supply chain less efficient, leading to an increase in overall costs.
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to user):
#
# By prohibiting the shipment from supplier 1 to roastery 2, the optimal cost of the supply chain increased from 2470.0 to 2760.0. This means the restriction made the supply chain less efficient, leading to an increase in overall costs.
#
# --------------------------------------------------------------------------------

# %%
user.initiate_chat(agent, message="What is the impact of supplier1 being able to supply only half the quantity at present?")
# Out:
# user (to OptiGuide Coffee Example):
#
# What is the impact of supplier1 being able to supply only half the quantity at present?
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Coffee Example):
#
# ```python
# # Decreasing the supply of supplier1 by 50%.
# updated_capacity_in_supplier = capacity_in_supplier.copy()
# updated_capacity_in_supplier['supplier1'] = capacity_in_supplier['supplier1'] / 2
#
# # Add updated supply constraints for supplier1
# model.addConstr(
#     sum(x[i] for i in shipping_cost_from_supplier_to_roastery.keys()
#         if i[0] == 'supplier1') <= updated_capacity_in_supplier['supplier1'],
#     f"new_supply_supplier1")
# ```
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to safeguard):
#
#
# --- Code ---
# # Decreasing the supply of supplier1 by 50%.
# updated_capacity_in_supplier = capacity_in_supplier.copy()
# updated_capacity_in_supplier['supplier1'] = capacity_in_supplier['supplier1'] / 2
#
# # Add updated supply constraints for supplier1
# model.addConstr(
#     sum(x[i] for i in shipping_cost_from_supplier_to_roastery.keys()
#         if i[0] == 'supplier1') <= updated_capacity_in_supplier['supplier1'],
#     f"new_supply_supplier1")
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# safeguard (to OptiGuide Coffee Example):
#
# SAFE
#
# --------------------------------------------------------------------------------
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 11 rows, 18 columns and 36 nonzeros
# Model fingerprint: 0x2d91b9ad
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 2e+02]
# Found heuristic solution: objective 3280.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 18 columns, 36 nonzeros
# Variable types: 0 continuous, 18 integer (0 binary)
# Found heuristic solution: objective 3276.0000000
#
# Root relaxation: objective 2.470000e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2470.0000000 2470.00000  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 2470 3276 3280
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.470000000000e+03, best bound 2.470000000000e+03, gap 0.0000%
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12 rows, 18 columns and 38 nonzeros
# Model fingerprint: 0x876c533d
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 2e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint new_supply_supplier1 by 5.000000000
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 18 columns, 36 nonzeros
# Variable types: 0 continuous, 18 integer (0 binary)
#
# Root relaxation: infeasible, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Sun Nov  5 18:52:46 2023
# Not solved to optimality. Optimization status: 3
#
# Computing Irreducible Inconsistent Subsystem (IIS)...
#
#            Constraints          |            Bounds           |  Runtime
#       Min       Max     Guess   |   Min       Max     Guess   |
# --------------------------------------------------------------------------
#         0        12         -         0        18         -           0s
#        11        11        11         0         0         0           0s
#
# IIS computed: 11 constraints, 0 bounds
# IIS runtime: 0.01 seconds (0.00 work units)
# infeasible
# Conflicting Constraints:
# ['flow_roastery1', 'flow_roastery2', 'supply_supplier3', 'supply_supplier2', 'light_demand_cafe3', 'dark_demand_cafe3', 'light_demand_cafe2', 'dark_demand_cafe2', 'light_demand_cafe1', 'dark_demand_cafe1', 'new_supply_supplier1']
# OptiGuide Coffee Example (to writer):
#
# Here are the execution results: infeasible
# Conflicting Constraints:
# ['flow_roastery1', 'flow_roastery2', 'supply_supplier3', 'supply_supplier2', 'light_demand_cafe3', 'dark_demand_cafe3', 'light_demand_cafe2', 'dark_demand_cafe2', 'light_demand_cafe1', 'dark_demand_cafe1', 'new_supply_supplier1']
#
# Can you organize these information to a human readable answer?
# Remember to compare the new results to the original results you obtained in the
# beginning.
#
# --- HUMAN READABLE ANSWER ---
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Coffee Example):
#
# When the supply quantity of supplier1 is reduced by 50%, the optimization problem becomes infeasible. This means that the supply chain no longer has enough resources to meet all the cafe demands for coffee.
#
# From the list of conflicting constraints, we can see that all flow, supply, and demand constraints are conflicting, indicating that the reduced supply from supplier1 causes a ripple effect disrupting the balance in the supply chain.
#
# In particular, the new supply constraint for supplier1 seems to cause a chain reaction affecting how much coffee roasteries are able to roast ('flow_roastery1', 'flow_roastery2') and in turn, how much coffee cafes can receive ('light_demand_cafe3', 'dark_demand_cafe3', 'light_demand_cafe2', 'dark_demand_cafe2', 'light_demand_cafe1', 'dark_demand_cafe1').
#
# This differs from the original result where the optimization problem had a solution with an optimal cost of 2470. Hence, it's critical to maintain supply levels to keep the supply chain functioning effectively.
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to user):
#
# When the supply quantity of supplier1 is reduced by 50%, the optimization problem becomes infeasible. This means that the supply chain no longer has enough resources to meet all the cafe demands for coffee.
#
# From the list of conflicting constraints, we can see that all flow, supply, and demand constraints are conflicting, indicating that the reduced supply from supplier1 causes a ripple effect disrupting the balance in the supply chain.
#
# In particular, the new supply constraint for supplier1 seems to cause a chain reaction affecting how much coffee roasteries are able to roast ('flow_roastery1', 'flow_roastery2') and in turn, how much coffee cafes can receive ('light_demand_cafe3', 'dark_demand_cafe3', 'light_demand_cafe2', 'dark_demand_cafe2', 'light_demand_cafe1', 'dark_demand_cafe1').
#
# This differs from the original result where the optimization problem had a solution with an optimal cost of 2470. Hence, it's critical to maintain supply levels to keep the supply chain functioning effectively.
#
# --------------------------------------------------------------------------------
